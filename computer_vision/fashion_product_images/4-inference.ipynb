# %% [markdown]
# <img src="static/images/datachain-logo.png" alt="Dataset" style="width: 200px;"/>
#
# # 🚀 Run Inference Jobs using Datachain (scalable batch scoring)
#
# In this tutorial, you'll learn how to run inference jobs on a large dataset using **[Datachain](https://github.com/iterative/datachain)** in batch processing. Batch inference is useful when you have a pre-trained model and want to make predictions on a dataset without needing real-time processing. **[Datachain](https://github.com/iterative/datachain)** provides a convenient way to run inference jobs on datasets stored in DataChain.
#
# ## 📋  Agenda
#
# 1. Load Pre-trained Model
# 2. Define Inference Classes
# 3. Run Inference
# 4. Save Predictions
#
# ## 🛠 Prerequisites
#
# Before you begin, ensure you have:
#
# - **[Datachain](https://github.com/iterative/datachain)** installed in your environment.
# - The necessary dependencies installed, including PyTorch and the required libraries.
# - Access to the pre-trained model file `model.pth`.
# - Access to the test dataset `fashion-test` for inference.

# %%
# %load_ext autoreload
# %autoreload 2

import os
import pathlib
import torch

from datachain import C, DataChain, DataModel
from datachain.lib.image import convert_image
from torch import optim

from src.train import CNN, transform

# %% [markdown]
# # 📥 Load Model (pre-trained)
#
# - Load the pre-trained model weights and optimizer state.
# - Create an instance of the `CNN` model.
# - Create an optimizer using `optim.SGD`.

# %%
#### Load Pre-trained Model  #####

checkpoint = torch.load("model.pth")
CLASSES = checkpoint["classes"]
NUM_CLASSES = len(CLASSES)

model = CNN(NUM_CLASSES)
optimizer = optim.SGD(model.parameters(), lr=0.001)
model.load_state_dict(checkpoint["model_state_dict"])
optimizer.load_state_dict(checkpoint["optimizer_state_dict"])

print(CLASSES)
print(NUM_CLASSES)
print(model, optimizer)
# Out:
# ['Casual', 'Ethnic', 'Sports', 'Formal', 'Party', 'Smart Casual', 'Travel', 'nan']
# 8
# CNN(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (fc1): Linear(in_features=4096, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=8, bias=True)
# ) SGD (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     nesterov: False
#     weight_decay: 0
# )
# /var/folders/28/ly259mjn413_8g33c4n20tvc0000gn/T/ipykernel_90815/1247583527.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load("model.pth")

# %% [markdown]
# By following these steps, you can easily load a pre-trained model and its associated optimizer state in PyTorch. This allows you to leverage the learned weights and continue training or perform inference without starting from scratch.

# %% [markdown]
# # ✅ Run Inference & Save Predictions
#
# - Load the `fashion-test` dataset.
# - Apply filters to select only 'Coffee' category images with non-empty `front_back` values.
# - Use `map()` to apply the `InferenceMapper` to each image in the dataset.
# - The `InferenceMapper` takes the image binary file as input and outputs the predicted class, probability, and label.
# - The `save()` method is used to save the dataset with the predicted values as `fashion-predictions`.

# %% [markdown]
# ## Define the inference classes

# %%
#### Inference #####

class Predictions(DataModel):
    pred_class: int
    pred_proba: float
    pred_label: str

class InferenceMapper():

    def __init__(self, model, classes):
        self.model = model
        self.classes = classes 
        
        self.model.eval()

    def predict(self, file) -> Predictions:

        img_raw = file.read()
        img = convert_image(img_raw, transform=transform).unsqueeze(0)
        
        with torch.no_grad():
            # emb = model(img)
            outputs = self.model(img)
        probs = torch.nn.functional.softmax(outputs, dim=1)
        confidence, predicted_classes = torch.max(probs, 1)

        return Predictions(
            pred_class=predicted_classes.item(),
            pred_proba=confidence.item(),
            pred_label=self.classes[predicted_classes.item()]
        )

inference_eng = InferenceMapper(model, CLASSES)

# %% [markdown]
# - Define a `Predictions` class that inherits from `DataModel` to store the predicted class, probability, and label.
# - Define an `InferenceMapper` class to perform the inference logic.

# %% [markdown]
# ## Run Inference

# %%
(
    DataChain.from_dataset("fashion-product-images")
    .filter((C("masterCategory") == "Apparel") & (C("subCategory") == "Topwear"))
    .limit(100)
    .settings(parallel=-1)    
    .map(predictions=lambda file: inference_eng.predict(file), output=Predictions)
    .save("fashion-predictions")
    .show(3)
)
# Out:
# Preparing: 100 rows [00:00, 33659.45 rows/s]
# /Users/mikhailrozhkov/.pyenv/versions/3.12.4/lib/python3.12/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# /Users/mikhailrozhkov/.pyenv/versions/3.12.4/lib/python3.12/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# /Users/mikhailrozhkov/.pyenv/versions/3.12.4/lib/python3.12/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# /Users/mikhailrozhkov/.pyenv/versions/3.12.4/lib/python3.12/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# /Users/mikhailrozhkov/.pyenv/versions/3.12.4/lib/python3.12/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# /Users/mikhailrozhkov/.pyenv/versions/3.12.4/lib/python3.12/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# /Users/mikhailrozhkov/.pyenv/versions/3.12.4/lib/python3.12/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# /Users/mikhailrozhkov/.pyenv/versions/3.12.4/lib/python3.12/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# /Users/mikhailrozhkov/.pyenv/versions/3.12.4/lib/python3.12/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# /Users/mikhailrozhkov/.pyenv/versions/3.12.4/lib/python3.12/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# /Users/mikhailrozhkov/.pyenv/versions/3.12.4/lib/python3.12/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# /Users/mikhailrozhkov/.pyenv/versions/3.12.4/lib/python3.12/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# Download: 0.00B [00:00, ?B/s]/Users/mikhailrozhkov/.pyenv/versions/3.12.4/lib/python3.12/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
#
# Download: 75.2kB [00:00, 621kB/s]s]
# Download: 136kB [00:00, 287kB/s] ows/s]
# Download: 183kB [00:00, 330kB/s] rows/s]
# Download: 230kB [00:00, 265kB/s] rows/s]
# Download: 263kB [00:01, 216kB/s] rows/s]
# Processed: 33 rows [00:00, 31.71 rows/s]
# Processed: 40 rows [00:01, 38.94 rows/s]
# Download: 290kB [00:01, 153kB/s] rows/s]
# Processed: 50 rows [00:01, 37.09 rows/s]
# Download: 310kB [00:01, 120kB/s] rows/s]
# Download: 326kB [00:01, 102kB/s] rows/s]
# Download: 339kB [00:02, 99.3kB/s]rows/s]
# Download: 372kB [00:02, 124kB/s] rows/s]
# Download: 388kB [00:02, 125kB/s] rows/s]
# Download: 402kB [00:02, 125kB/s] rows/s]
# Processed: 89 rows [00:02, 35.65 rows/s]
# Download: 416kB [00:02, 108kB/s] rows/s]
# Download: 423kB [00:03, 120kB/s] rows/s]
# Processed: 100 rows [00:03, 28.45 rows/s]
# Saving: 100 rows [00:00, 42974.43 rows/s]
# Cleanup: 2 tables [00:00, 4650.00 tables/s]
#                   file                                     file   file  \
#                 source                                     path   size
# 0  gs://datachain-demo  fashion-product-images/images/10003.jpg  11564
# 1  gs://datachain-demo  fashion-product-images/images/10005.jpg  16677
# 2  gs://datachain-demo  fashion-product-images/images/10006.jpg   2146
#
#                file              file      file  \
#             version              etag is_latest
# 0  1719489683599343  CO/fpJ7e+4YDEAE=         1
# 1  1719489744441124  CKSeprve+4YDEAE=         1
# 2  1719489713329967  CK+uu6ze+4YDEAE=         1
#
#                               file     file  file   filename gender  \
#                      last_modified location vtype
# 0 2024-06-27 12:01:23.651000+00:00     None        10003.jpg  Women
# 1 2024-06-27 12:02:24.500000+00:00     None        10005.jpg    Men
# 2 2024-06-27 12:01:53.379000+00:00     None        10006.jpg    Men
#
#   mastercategory subcategory articletype basecolour season    year   usage  \
#
# 0        Apparel     Topwear     Tshirts      White   Fall  2011.0  Sports
# 1        Apparel     Topwear     Tshirts       Blue   Fall  2011.0  Sports
# 2        Apparel     Topwear     Tshirts      Black   Fall  2011.0  Sports
#
#                        productdisplayname right_filename predictions  \
#                                                           pred_class
# 0  Nike Women As Nike Eleme White T-Shirt      10003.jpg           0
# 1    Nike Men As Ss Trainin Blue T-Shirts      10005.jpg           2
# 2           Nike Men AS T90 Black Tshirts      10006.jpg           2
#
#   predictions predictions
#    pred_proba  pred_label
# 0    0.689517      Casual
# 1    0.469780      Sports
# 2    0.538664      Sports
# [Limited by 3 rows]

# %% [markdown]
# ## Explore predictions

# %%
preds = DataChain.from_dataset("fashion-predictions").select("predictions")
print(preds.count())
preds.to_pandas(flatten=True)['predictions.pred_label'].value_counts()
# Out:
# 100
# predictions.pred_label
# Casual    87
# Sports     9
# Formal     4
# Name: count, dtype: int64

# %% [markdown]
# ## Delta Updates
#
# - Assume we already calculated predictions for 'old' dataset (for this example assume it's all images added before 2017)
# - The 'new' dataset contains some images added after 2017
# - We want to calculate inference for this delta updates only

# %%
# Prepare datasets

old = (
    DataChain.from_dataset("fashion-product-images")
    .filter(C("masterCategory") == "Apparel" and C("subCategory") == "Topwear")
    .filter(C("year") < 2017)
    # .limit(3)
)
print(old.count())

new = (
    DataChain.from_dataset("fashion-product-images")
    .filter(C("masterCategory") == "Apparel" and C("subCategory") == "Topwear")
    .filter(C("year") >= 2017)
    .limit(100)
)
print(new.count())

update = new.subtract(old)
print(update.count())
# Out:
# 20933
# 100
# Cleanup: 1 tables [00:00, 3331.46 tables/s]
# 100

# %%
update_predictions = (
    update
    .map(predictions=lambda file: inference_eng.predict(file), output=Predictions)
    .save()
)

update_predictions.count()
# Out:
# Preparing: 100 rows [00:00, 50889.40 rows/s]
# Download: 0.00B [00:00, ?B/s]
# Download: 20.8kB [00:00, 53.4kB/s]]
# Download: 43.5kB [00:00, 61.5kB/s]ws/s]
# Download: 60.5kB [00:01, 51.2kB/s]ws/s]
# Download: 79.9kB [00:01, 55.9kB/s]ws/s]
# Processed: 5 rows [00:01,  3.18 rows/s]
# Download: 89.9kB [00:02, 32.1kB/s]ws/s]
# Download: 105kB [00:02, 36.3kB/s] ws/s]
# Download: 131kB [00:02, 49.2kB/s]ows/s]
# Download: 139kB [00:03, 36.8kB/s]ows/s]
# Download: 152kB [00:03, 38.2kB/s]rows/s]
# Download: 160kB [00:04, 34.7kB/s]rows/s]
# Download: 189kB [00:04, 48.6kB/s]rows/s]
# Download: 210kB [00:04, 54.0kB/s]rows/s]
# Download: 231kB [00:05, 57.0kB/s]rows/s]
# Download: 252kB [00:05, 57.7kB/s]rows/s]
# Download: 270kB [00:05, 56.4kB/s]rows/s]
# Download: 289kB [00:06, 57.7kB/s]rows/s]
# Download: 313kB [00:06, 61.4kB/s]rows/s]
# Download: 329kB [00:06, 54.3kB/s]rows/s]
# Download: 356kB [00:07, 63.5kB/s]rows/s]
# Download: 364kB [00:07, 53.0kB/s]rows/s]
# Download: 380kB [00:07, 53.0kB/s]rows/s]
# Download: 398kB [00:08, 54.3kB/s]rows/s]
# Download: 416kB [00:08, 53.1kB/s]rows/s]
# Download: 433kB [00:08, 54.7kB/s]rows/s]
# Download: 441kB [00:09, 44.4kB/s]rows/s]
# Download: 464kB [00:09, 53.1kB/s]rows/s]
# Download: 471kB [00:09, 45.0kB/s]rows/s]
# Processed: 29 rows [00:09,  3.14 rows/s]
# Download: 478kB [00:10, 31.1kB/s]rows/s]
# Download: 486kB [00:10, 28.8kB/s]rows/s]
# Download: 502kB [00:10, 34.8kB/s]rows/s]
# Download: 510kB [00:11, 31.9kB/s]rows/s]
# Download: 527kB [00:11, 37.7kB/s]rows/s]
# Download: 549kB [00:11, 46.9kB/s]rows/s]
# Download: 563kB [00:12, 44.3kB/s]rows/s]
# Download: 597kB [00:12, 61.4kB/s]rows/s]
# Download: 618kB [00:12, 63.0kB/s]rows/s]
# Download: 629kB [00:13, 52.8kB/s]rows/s]
# Download: 651kB [00:13, 57.4kB/s]rows/s]
# Download: 670kB [00:14, 55.1kB/s]rows/s]
# Download: 681kB [00:14, 51.0kB/s]rows/s]
# Processed: 43 rows [00:14,  3.00 rows/s]
# Download: 690kB [00:14, 35.3kB/s]rows/s]
# Download: 713kB [00:15, 45.8kB/s]rows/s]
# Download: 731kB [00:15, 50.2kB/s]rows/s]
# Download: 748kB [00:15, 52.7kB/s]rows/s]
# Processed: 48 rows [00:15,  3.30 rows/s]
# Download: 755kB [00:16, 35.1kB/s]rows/s]
# Download: 763kB [00:16, 32.0kB/s]rows/s]
# Download: 782kB [00:17, 37.7kB/s]rows/s]
# Download: 806kB [00:17, 47.7kB/s]rows/s]
# Download: 823kB [00:17, 49.6kB/s]rows/s]
# Download: 839kB [00:18, 50.8kB/s]rows/s]
# Download: 852kB [00:18, 47.5kB/s]rows/s]
# Download: 860kB [00:18, 40.2kB/s]rows/s]
# Download: 881kB [00:19, 46.7kB/s]rows/s]
# Download: 904kB [00:19, 55.5kB/s]rows/s]
# Download: 922kB [00:19, 57.4kB/s]rows/s]
# Processed: 60 rows [00:19,  3.16 rows/s]
# Download: 930kB [00:20, 37.8kB/s]rows/s]
# Download: 938kB [00:20, 34.2kB/s]rows/s]
# Download: 964kB [00:20, 47.2kB/s]rows/s]
# Download: 982kB [00:21, 48.0kB/s]rows/s]
# Download: 0.98MB [00:21, 56.5kB/s]ows/s]
# Download: 1.00MB [00:21, 56.9kB/s]ows/s]
# Download: 1.01MB [00:22, 49.2kB/s]ows/s]
# Download: 1.02MB [00:22, 41.4kB/s]ows/s]
# Download: 1.04MB [00:23, 49.4kB/s]ows/s]
# Download: 1.06MB [00:23, 56.1kB/s]ows/s]
# Download: 1.07MB [00:23, 46.3kB/s]ows/s]
# Download: 1.08MB [00:23, 44.1kB/s]ows/s]
# Processed: 73 rows [00:23,  3.14 rows/s]
# Download: 1.09MB [00:24, 31.3kB/s]ows/s]
# Download: 1.10MB [00:24, 29.2kB/s]ows/s]
# Download: 1.10MB [00:25, 24.8kB/s]ows/s]
# Download: 1.11MB [00:25, 25.0kB/s]ows/s]
# Download: 1.12MB [00:25, 27.4kB/s]ows/s]
# Download: 1.14MB [00:26, 36.4kB/s]ows/s]
# Download: 1.16MB [00:26, 45.4kB/s]ows/s]
# Download: 1.17MB [00:26, 47.8kB/s]ows/s]
# Download: 1.19MB [00:27, 49.8kB/s]ows/s]
# Download: 1.22MB [00:27, 61.2kB/s]ows/s]
# Download: 1.23MB [00:27, 55.9kB/s]ows/s]
# Download: 1.24MB [00:28, 45.5kB/s]ows/s]
# Download: 1.25MB [00:28, 38.2kB/s]ows/s]
# Download: 1.28MB [00:28, 56.0kB/s]ows/s]
# Download: 1.30MB [00:29, 59.3kB/s]ows/s]
# Download: 1.32MB [00:29, 59.2kB/s]ows/s]
# Download: 1.33MB [00:29, 53.5kB/s]ows/s]
# Download: 1.35MB [00:30, 56.2kB/s]ows/s]
# Download: 1.35MB [00:30, 45.8kB/s]ows/s]
# Download: 1.38MB [00:30, 52.0kB/s]ows/s]
# Download: 1.39MB [00:31, 54.5kB/s]ows/s]
# Download: 1.40MB [00:31, 48.7kB/s]ows/s]
# Download: 1.42MB [00:31, 51.6kB/s]ows/s]
# Download: 1.43MB [00:31, 49.3kB/s]ows/s]
# Processed: 98 rows [00:31,  3.19 rows/s]
# Download: 1.44MB [00:32, 33.5kB/s]ows/s]
# Download: 1.46MB [00:32, 46.8kB/s]rows/s]
# Processed: 100 rows [00:32,  3.06 rows/s]
# Saving: 100 rows [00:00, 40206.13 rows/s]
# Cleanup: 4 tables [00:00, 4450.19 tables/s]
# 100

# %%
# Size of Predictions before the union (old)

DataChain.from_dataset("fashion-predictions").count()
# Out:
# 100

# %%
# Add (union) new predictions and save (as a new version)

(
    DataChain.from_dataset("fashion-predictions")
    .union(update_predictions, )
    .distinct("file.path")
    .save("fashion-predictions")
)
# Out:
# Saving: 200 rows [00:00, 36750.23 rows/s]

# %%
# Size of Predictions after union

DataChain.from_dataset("fashion-predictions").count()
# Out:
# 200

# %% [markdown]
# # 🔍 Analyze Predictions
#
# After running inference on your test dataset and generating predictions, it's crucial to analyze the results to gain insights into your model's performance.
#
# DataChain provides powerful tools to filter and examine the predictions, allowing you to identify correct predictions, incorrect predictions, and explore different confidence levels. Let's break down the code:

# %% [markdown]
# ## Show correct predictions
#
# - Load the "fashion-predictions" dataset, which contains the predicted labels and probabilities along with the ground truth labels.
# - Filter the dataset to include only the correct predictions where the predicted label (`pred_label`) matches the ground truth label (`usage`).

# %%
# Show correct predictions

(
    DataChain.from_dataset("fashion-predictions")
    .filter(C("usage") == C("predictions").pred_label)
    .show(5)
)
# Out:
#                   file                                     file   file  \
#                 source                                     path   size
# 0  gs://datachain-demo  fashion-product-images/images/10005.jpg  16677
# 1  gs://datachain-demo  fashion-product-images/images/10006.jpg   2146
# 2  gs://datachain-demo  fashion-product-images/images/10008.jpg   1881
# 3  gs://datachain-demo  fashion-product-images/images/10010.jpg  14601
# 4  gs://datachain-demo  fashion-product-images/images/10015.jpg   2030
#
#                file              file      file  \
#             version              etag is_latest
# 0  1719489744441124  CKSeprve+4YDEAE=         1
# 1  1719489713329967  CK+uu6ze+4YDEAE=         1
# 2  1719489501603681  COHOwMfd+4YDEAE=         1
# 3  1719489733476370  CJKAibbe+4YDEAE=         1
# 4  1719489639220458  COqJkIne+4YDEAE=         1
#
#                               file     file  file   filename gender  \
#                      last_modified location vtype
# 0 2024-06-27 12:02:24.500000+00:00     None        10005.jpg    Men
# 1 2024-06-27 12:01:53.379000+00:00     None        10006.jpg    Men
# 2 2024-06-27 11:58:21.655000+00:00     None        10008.jpg    Men
# 3 2024-06-27 12:02:13.521000+00:00     None        10010.jpg    Men
# 4 2024-06-27 12:00:39.279000+00:00     None        10015.jpg    Men
#
#   mastercategory subcategory articletype basecolour season    year   usage  \
#
# 0        Apparel     Topwear     Tshirts       Blue   Fall  2011.0  Sports
# 1        Apparel     Topwear     Tshirts      Black   Fall  2011.0  Sports
# 2        Apparel     Topwear     Tshirts  Navy Blue   Fall  2011.0  Sports
# 3        Apparel     Topwear     Tshirts      Black   Fall  2011.0  Sports
# 4        Apparel     Topwear     Tshirts      White   Fall  2011.0  Casual
#
#                             productdisplayname right_filename predictions  \
#                                                                pred_class
# 0         Nike Men As Ss Trainin Blue T-Shirts      10005.jpg           2
# 1                Nike Men AS T90 Black Tshirts      10006.jpg           2
# 2             Nike Men Town Navy Blue T-Shirts      10008.jpg           2
# 3        Nike Men As Showdown F Black T-Shirts      10010.jpg           2
# 4  Locomotive Men American Glory White Tshirts      10015.jpg           0
#
#   predictions predictions
#    pred_proba  pred_label
# 0    0.469780      Sports
# 1    0.538664      Sports
# 2    0.511849      Sports
# 3    0.584874      Sports
# 4    0.982861      Casual
# [Limited by 5 rows]

# %% [markdown]
# ## Show incorrect predictions
#
# - Filter the dataset to include only the incorrect predictions where the predicted label (`pred_label`) does not match the ground truth label (`usage`).
# - Assign the filtered dataset to the variable `mistakes`.

# %%
# Show incorrect predictions

mistakes = (
    DataChain.from_dataset("fashion-predictions")
    .filter(C("usage") != C("predictions").pred_label)
    .select("file", "usage", "predictions")
)
mistakes.show(5)
# Out:
#                   file                                     file   file  \
#                 source                                     path   size
# 0  gs://datachain-demo  fashion-product-images/images/10003.jpg  11564
# 1  gs://datachain-demo  fashion-product-images/images/10007.jpg  18895
# 2  gs://datachain-demo  fashion-product-images/images/10009.jpg  17019
# 3  gs://datachain-demo  fashion-product-images/images/10013.jpg  15607
# 4  gs://datachain-demo  fashion-product-images/images/10017.jpg  15516
#
#                file              file      file  \
#             version              etag is_latest
# 0  1719489683599343  CO/fpJ7e+4YDEAE=         1
# 1  1719489701142466  CMK/06be+4YDEAE=         1
# 2  1719489513563157  CJXIms3d+4YDEAE=         1
# 3  1719489701351938  CIKk4Kbe+4YDEAE=         1
# 4  1719489683394315  CIuemJ7e+4YDEAE=         1
#
#                               file     file  file   usage predictions  \
#                      last_modified location vtype          pred_class
# 0 2024-06-27 12:01:23.651000+00:00     None        Sports           0
# 1 2024-06-27 12:01:41.201000+00:00     None        Sports           0
# 2 2024-06-27 11:58:33.614000+00:00     None        Sports           0
# 3 2024-06-27 12:01:41.402000+00:00     None        Sports           0
# 4 2024-06-27 12:01:23.451000+00:00     None        Sports           0
#
#   predictions predictions
#    pred_proba  pred_label
# 0    0.689517      Casual
# 1    0.713078      Casual
# 2    0.537340      Casual
# 3    0.528282      Casual
# 4    0.589856      Casual
# [Limited by 5 rows]

# %%
df = mistakes.to_pandas()
print(df.shape)

df["predictions", "pred_proba"].hist()
# Out:
# (28, 13)
# <Axes: >

# %%
HIGH_CONF = df["predictions", "pred_proba"].quantile(0.8)
LOW_CONF = df["predictions", "pred_proba"].quantile(0.5)

print(LOW_CONF, HIGH_CONF)
# Out:
# 0.6337079405784607 0.704708194732666

# %% [markdown]
# ## Analyze high-confidence and low-confidence mistakes
#
# - Filter the `mistakes` dataset
#     -  `high-confidence` are mistakes where the predicted probability (`pred_proba`) is more than 0.5.
#     -  `low-confidence` are mistakes where the predicted probability (`pred_proba`) is less than 0.5.
# - Order the filtered dataset by the predicted probability in ascending order using `order_by(C("pred_proba").asc())`.
# - Convert the filtered and ordered dataset to a pandas DataFrame using `to_pandas()`.
# - Print the shape of the resulting DataFrame to see the number of low-confidence mistakes.
# - Display the first 3 low-confidence mistakes using `head(3)`.

# %%
# Find high-confidence mistakes

high_conf_mist =(
    mistakes
    .filter(C("predictions.pred_proba") > HIGH_CONF )
    .order_by("predictions.pred_proba", descending=True)
)

print(high_conf_mist.to_pandas().shape)
high_conf_mist.show(5)
# Out:
# (6, 13)
#                   file                                     file   file  \
#                 source                                     path   size
# 0  gs://datachain-demo  fashion-product-images/images/10054.jpg   1502
# 1  gs://datachain-demo  fashion-product-images/images/27432.jpg    863
# 2  gs://datachain-demo  fashion-product-images/images/10029.jpg   1930
# 3  gs://datachain-demo  fashion-product-images/images/10007.jpg  18895
# 4  gs://datachain-demo  fashion-product-images/images/10184.jpg   1321
#
#                file              file      file  \
#             version              etag is_latest
# 0  1719489419673028  CMT7t6Dd+4YDEAE=         1
# 1  1719489772563483  CJvY2sje+4YDEAE=         1
# 2  1719489640209116  CNy1zIne+4YDEAE=         1
# 3  1719489701142466  CMK/06be+4YDEAE=         1
# 4  1719489583067255  CPfgrO7d+4YDEAE=         1
#
#                               file     file  file   usage predictions  \
#                      last_modified location vtype          pred_class
# 0 2024-06-27 11:56:59.711000+00:00     None        Sports           0
# 1 2024-06-27 12:02:52.614000+00:00     None        Sports           0
# 2 2024-06-27 12:00:40.269000+00:00     None        Sports           0
# 3 2024-06-27 12:01:41.201000+00:00     None        Sports           0
# 4 2024-06-27 11:59:43.126000+00:00     None        Casual           3
#
#   predictions predictions
#    pred_proba  pred_label
# 0    0.962668      Casual
# 1    0.794838      Casual
# 2    0.740084      Casual
# 3    0.713078      Casual
# 4    0.707810      Formal
# [Limited by 5 rows]

# %%
# Find low-confidence mistakes

low_conf_mist = (
    mistakes
    .filter(C("predictions.pred_proba") < LOW_CONF )
    .order_by("predictions.pred_proba")
)

print(low_conf_mist.to_pandas().shape)
low_conf_mist.show(3)
# Out:
# (14, 13)
#                   file                                     file   file  \
#                 source                                     path   size
# 0  gs://datachain-demo  fashion-product-images/images/10019.jpg   2503
# 1  gs://datachain-demo  fashion-product-images/images/10190.jpg   2178
# 2  gs://datachain-demo  fashion-product-images/images/36265.jpg  15430
#
#                file              file      file  \
#             version              etag is_latest
# 0  1719489605320971  CIuC+/jd+4YDEAE=         1
# 1  1719489583713249  COGX1O7d+4YDEAE=         1
# 2  1719489773060013  CK3/+Mje+4YDEAE=         1
#
#                               file     file  file   usage predictions  \
#                      last_modified location vtype          pred_class
# 0 2024-06-27 12:00:05.371000+00:00     None        Sports           0
# 1 2024-06-27 11:59:43.765000+00:00     None        Casual           3
# 2 2024-06-27 12:02:53.106000+00:00     None        Casual           1
#
#   predictions predictions
#    pred_proba  pred_label
# 0    0.452192      Casual
# 1    0.461946      Formal
# 2    0.483733      Ethnic
# [Limited by 3 rows]

# %% [markdown]
# # 📊 Visualize mistakes

# %% [markdown]
# We can use `DataChain.collect()` to extract the values from the sample. Here's an example of collecting a subset of column signals from the sample:

# %%
sample_results = list(high_conf_mist.collect())
sample_results[0]
# Out:
# (ImageFile(source='gs://datachain-demo', path='fashion-product-images/images/10054.jpg', size=1502, version='1719489419673028', etag='CMT7t6Dd+4YDEAE=', is_latest=True, last_modified=datetime.datetime(2024, 6, 27, 11, 56, 59, 711000, tzinfo=datetime.timezone.utc), location=None, vtype=''),
#  'Sports',
#  Predictions(pred_class=0, pred_proba=0.9626676440238953, pred_label='Casual'))

# %% [markdown]
# The example has an output for each signal:
# - `file` returns a special `ImageFile` object (see below).
# - `usage` returns an original target class name
# - `predictions` returns prediction data fields.
#
# DataChain knows to treat `file` as an `ImageFile` because we created the chain for the image files with `DataChain.from_storage(..., type="image")`. `ImageFile` is a "DataModel" in Datachain, and you can use `.read()` to get its value, which for `ImageFile` returns the image itself.

# %%
example = sample_results[0]
example[0].read()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80>

# %%
# Prepare utility function to display sample results

import matplotlib.pyplot as plt
import numpy as np

def display_image_matrix(items, top):
    # Constants for the layout
    columns = 5
    rows = int(np.ceil(top / columns))

    # Create subplots
    fig, ax_arr = plt.subplots(rows, columns, figsize=(15, 3 * rows))
    fig.suptitle("Displaying images", fontsize=20)
    ax_arr = ax_arr.flatten() # Flatten the array of axes, in case of a single row

    # Plot images
    for i in range(top):
        if i < len(items):  # Check to avoid index error if less items than top
            img = items[i][0].read()  # Retrieve the image
            true_class = items[i][1]
            preds = items[i][2].model_dump()
            pred_class = preds['pred_label']

            # Set image and title
            ax_arr[i].imshow(img)
            ax_arr[i].set_title(f"True: {true_class}\nPred: {pred_class}", fontsize=14, backgroundcolor='white')
            ax_arr[i].axis('off')  # Hide axes
        else:
            ax_arr[i].axis('off')  # Hide unused subplots

    # Adjust layout and padding
    plt.tight_layout(pad=2.0)
    plt.show()

# %% [markdown]
# ## Explore Low Confidence Mistakes

# %%
# Low Confidence Mistakes

TOP = 10
# for item in low_conf_mist.limit(TOP).collect():
#     display(item[0].read())
    
items = list(low_conf_mist.limit(TOP).collect())
display_image_matrix(items, TOP)

# %% [markdown]
# ## Explore High Confidence Mistakes

# %%
## How Confidence Mistakes

TOP = 10
# for item in high_conf_mist.limit(TOP).collect():
#     display(item[0].read())

items = list(high_conf_mist.limit(TOP).collect())
display_image_matrix(items, TOP)

# %% [markdown]
# ## Explore Correct Predictions

# %%
correct_preds = (
    DataChain.from_dataset("fashion-predictions")
    .filter(C("usage") == C("predictions.pred_label"))
    .order_by("predictions.pred_proba", descending=True)
    .select("file", "usage", "predictions")
)

print(correct_preds.to_pandas().shape)
correct_preds.show(5)
# Out:
# (172, 13)
#                   file                                     file  file  \
#                 source                                     path  size
# 0  gs://datachain-demo  fashion-product-images/images/10359.jpg  2032
# 1  gs://datachain-demo  fashion-product-images/images/10377.jpg  1639
# 2  gs://datachain-demo  fashion-product-images/images/10072.jpg  2035
# 3  gs://datachain-demo  fashion-product-images/images/10361.jpg  2214
# 4  gs://datachain-demo  fashion-product-images/images/10015.jpg  2030
#
#                file              file      file  \
#             version              etag is_latest
# 0  1719489692779024  CJCE1aLe+4YDEAE=         1
# 1  1719489632107261  CP313YXe+4YDEAE=         1
# 2  1719489864265239  CJfct/Te+4YDEAE=         1
# 3  1719489690571136  CICjzqHe+4YDEAE=         1
# 4  1719489639220458  COqJkIne+4YDEAE=         1
#
#                               file     file  file   usage predictions  \
#                      last_modified location vtype          pred_class
# 0 2024-06-27 12:01:32.822000+00:00     None        Casual           0
# 1 2024-06-27 12:00:32.160000+00:00     None        Casual           0
# 2 2024-06-27 12:04:24.316000+00:00     None        Casual           0
# 3 2024-06-27 12:01:30.619000+00:00     None        Casual           0
# 4 2024-06-27 12:00:39.279000+00:00     None        Casual           0
#
#   predictions predictions
#    pred_proba  pred_label
# 0    0.993556      Casual
# 1    0.992341      Casual
# 2    0.989428      Casual
# 3    0.983226      Casual
# 4    0.982861      Casual
# [Limited by 5 rows]

# %%
TOP = 10
# for item in high_conf_mist.limit(TOP).collect():
#     display(item[0].read())

items = list(correct_preds.limit(TOP).collect())
display_image_matrix(items, TOP)

# %% [markdown]
# # ☁️ Run in Studio (SaaS)
#
# <a href="https://datachain.ai/">
#     <img src="static/images/studio.png" alt="DataChain Studio SaaS" style="width: 600px;"/>
# </a>

# %% [markdown]
# To run these examples in Studio, follow the guide.
#
# 1. Open Studio / YOUR_TEAM / `datasets` workspace
# 2. Create a new Python Script
# 3. Copy/paste scripts from this Jupyter Notebook
# 4. Specify Settings:
#    - Computer vision dependencies
#    - pre-trained model `model.pth`
#    - import `train.py` module
# 5. Click the Run button

# %% [markdown]
# # 🎉 Summary
#
# **🌟 Congratulations! You've Successfully Completed the Inference Jobs with DataChain Tutorial! 🌟**
#
# In this tutorial, you've gained a wealth of knowledge and skills that will elevate your computer vision projects to new heights. Let's recap the key topics covered:
#
# 1. 🔍 **Running Inference:** You unleashed the power of your model to make predictions on real-world fashion images.
# 2. 📊 **Saving Predictions:** You discovered how to save model predictions, probabilities, and true labels into a DataChain dataset for further analysis.
# 3. 🔍 **Analyzing Predictions:** You explored DataChain's querying and filtering capabilities to identify correct predictions, high-confidence mistakes, and low-confidence mistakes, gaining valuable insights into your model's performance.
#
#
# Once again, congratulations on your incredible achievement!
#
# ## What's Next?
#
# Keep exploring, experimenting, and pushing the boundaries of what's possible in computer vision.  Check out the next parts of our tutorial series:
# - 📚 Check other tutorials and User Guides
# - 🔍 Try DataChain on your projects
#
# By mastering these techniques, you'll be well on your way to building powerful and efficient computer vision pipelines with DataChain.
#
# ## Get Involved
#
# We'd love to have you join our growing community of DataChain users and contributors! Here's how you can get involved:
# - ⭐ Give us a star on [GitHub](https://github.com/iterative/datachain) to show your support
# - 🌐 Visit the [datachain.ai website](https://datachain.ai/) to learn more about our products and services
# - 📞 Contact us to discuss how DataChain can help streamline your company's ML workflows
# - 🙌 Follow us on social media for the latest updates and insights
#
# Thanks for choosing DataChain, and happy coding! 😄
